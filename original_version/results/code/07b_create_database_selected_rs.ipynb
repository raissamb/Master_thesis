# %% [markdown]
# # Create the database for the selected repeat stations
#
# ## Description
#
# This program does the following:
# - It calculates the distance among each selected repeat station
# - It creates the database file for the selected repeat stations

# %%
# Import modules
import mestrado_module as mm
from pathlib import Path
import numpy as np
import pandas as pd

# %%
# Repeat station IGRF database info
rs_igrf_folder: Path = Path(mm.path_pipeline_04_igrf_calc)
rs_igrf_file: Path = Path(mm.output_4e_code_complete_rs_igrf_database)

# Folium file
folium_file_folder: Path = Path(mm.path_pipeline_07_select_rs_geo_distribution)
folium_file: Path = Path(mm.output_7a_code_selected_rs_folium)

# Output file
output_folder: Path = Path(mm.path_pipeline_07_select_rs_geo_distribution)
selected_rs_database_file: Path = Path(mm.output_7b_code_selected_rs_db)
selected_database_table_ref: Path = Path(mm.output_7b_code_selected_rs_table)
distances_file: Path = Path(mm.output_7b_code_distance_file)

# %% [markdown]
# ## Read the data

# %%
# Folium file with selected repeat stations
df_folium = pd.read_csv(folium_file_folder / folium_file)

# Sort values in ascending order by the Code column
df_folium = df_folium.drop(columns=["geometry"])
df_folium = df_folium.sort_values(by = "Code", ascending = True)
df_folium = df_folium.reset_index()
df_folium.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 40 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     50 non-null     int64
#  1   Code                      50 non-null     object
#  2   Lat_dd                    50 non-null     float64
#  3   Lon_dd                    50 non-null     float64
#  4   Alt_m                     50 non-null     float64
#  5   Time_dy                   50 non-null     float64
#  6   D_dd                      50 non-null     float64
#  7   IGRF_D_dd                 50 non-null     float64
#  8   I_dd                      50 non-null     float64
#  9   IGRF_I_dd                 50 non-null     float64
#  10  F_nT                      50 non-null     float64
#  11  IGRF_F_nT                 50 non-null     float64
#  12  H_nT                      50 non-null     float64
#  13  IGRF_H_nT                 50 non-null     float64
#  14  X_nT                      50 non-null     float64
#  15  IGRF_X_nT                 50 non-null     float64
#  16  Calculated_X              50 non-null     float64
#  17  Y_nT                      29 non-null     float64
#  18  IGRF_Y_nT                 50 non-null     float64
#  19  Calculated_Y              50 non-null     float64
#  20  Z_nT                      29 non-null     float64
#  21  IGRF_Z_nT                 50 non-null     float64
#  22  Calculated_Z              50 non-null     float64
#  23  N_occupations             50 non-null     int64
#  24  Closest_OBS               50 non-null     object
#  25  TTB_distances_km          50 non-null     float64
#  26  VSS_distances_km          50 non-null     float64
#  27  State                     50 non-null     object
#  28  Region                    50 non-null     object
#  29  RS_name                   50 non-null     object
#  30  RMSE_D_Original_values    50 non-null     float64
#  31  RMSE_I_Original_values    50 non-null     float64
#  32  RMSE_F_Original_values    50 non-null     float64
#  33  RMSE_H_Original_values    50 non-null     float64
#  34  RMSE_X_Original_values    50 non-null     float64
#  35  RMSE_X_Calculated_values  50 non-null     float64
#  36  RMSE_Y_Original_values    47 non-null     float64
#  37  RMSE_Y_Calculated_values  50 non-null     float64
#  38  RMSE_Z_Original_values    47 non-null     float64
#  39  RMSE_Z_Calculated_values  50 non-null     float64
# dtypes: float64(33), int64(2), object(5)
# memory usage: 15.8+ KB

# %%
## Read the rs igrf database
df_rs_igrf = pd.read_csv(rs_igrf_folder / rs_igrf_file)
df_rs_igrf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1082 entries, 0 to 1081
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Code                      1082 non-null   object
#  1   Lat_dd                    1082 non-null   float64
#  2   Lon_dd                    1082 non-null   float64
#  3   Alt_m                     1082 non-null   float64
#  4   Time_dy                   1082 non-null   float64
#  5   D_dd                      1082 non-null   float64
#  6   IGRF_D_dd                 1082 non-null   float64
#  7   I_dd                      1082 non-null   float64
#  8   IGRF_I_dd                 1082 non-null   float64
#  9   F_nT                      1082 non-null   float64
#  10  IGRF_F_nT                 1082 non-null   float64
#  11  H_nT                      1082 non-null   float64
#  12  IGRF_H_nT                 1082 non-null   float64
#  13  X_nT                      1082 non-null   float64
#  14  IGRF_X_nT                 1082 non-null   float64
#  15  Calculated_X              1082 non-null   float64
#  16  Y_nT                      1000 non-null   float64
#  17  IGRF_Y_nT                 1082 non-null   float64
#  18  Calculated_Y              1082 non-null   float64
#  19  Z_nT                      999 non-null    float64
#  20  IGRF_Z_nT                 1082 non-null   float64
#  21  Calculated_Z              1082 non-null   float64
#  22  N_occupations             1082 non-null   int64
#  23  Closest_OBS               1082 non-null   object
#  24  TTB_distances_km          1082 non-null   float64
#  25  VSS_distances_km          1082 non-null   float64
#  26  State                     1082 non-null   object
#  27  Region                    1082 non-null   object
#  28  RS_name                   1082 non-null   object
#  29  RMSE_D_Original_values    1082 non-null   float64
#  30  RMSE_I_Original_values    1082 non-null   float64
#  31  RMSE_F_Original_values    1082 non-null   float64
#  32  RMSE_H_Original_values    1082 non-null   float64
#  33  RMSE_X_Original_values    1082 non-null   float64
#  34  RMSE_X_Calculated_values  1082 non-null   float64
#  35  RMSE_Y_Original_values    1059 non-null   float64
#  36  RMSE_Y_Calculated_values  1082 non-null   float64
#  37  RMSE_Z_Original_values    1059 non-null   float64
#  38  RMSE_Z_Calculated_values  1082 non-null   float64
# dtypes: float64(33), int64(1), object(5)
# memory usage: 329.8+ KB

# %% [markdown]
# ## Calculate the distances (km) between each selected repeat station

# %%
# Create new dataframe to work on
calc_distances = df_folium

# Calculate the number of stations in this category
list_stations = calc_distances.Code.unique() 
list_stations_size = len(list_stations)
#print(list_stations)
print(list_stations_size)

# Create a new dataframe to hold the calculated distances in km
rs_distances = pd.DataFrame(columns=[list_stations], index=range(list_stations_size))

# Calculate the distances (FIND A BETTER WAY TO DO THIS LATER), result in km
for i in range(list_stations_size):
    rs_distances[list_stations[i]] = mm.haversine_array(calc_distances["Lon_dd"], calc_distances["Lat_dd"], calc_distances.loc[i].at["Lon_dd"], calc_distances.loc[i].at["Lat_dd"])
    
    
# Add another column with the stations code to server as visual index
rs_distances.insert(loc = 0, column="Stations (distances in km)", value = list_stations)

# Save it to a file
rs_distances.to_csv(output_folder / distances_file, index=False, float_format="%.3f", na_rep="NaN")

# View it
#rs_distances
# Out:
# 50

# %%
# This organize the dataframe into the lowest to highest distance between stations for the selected column (meaning station)
# the "chosen_station" variable the station you want ([0] is the first column/station), then it shows all the stations closest to it in decrescent order (closer and then farther)
# The rows variable indicates how many rows you want to see (meaning how many stations do you want to know the distance of in relation to the chosen station "chosen_station")
chosen_station = [list_stations[0]]
rows = list_stations_size
lowest_dist = rs_distances.nsmallest(rows, rs_distances[chosen_station])
#lowest_dist

# %% [markdown]
# ## Create a list with the selected repeat stations to use in the database creation

# %%
selected_rs_list = df_folium["Code"].tolist()
selected_rs_list_size = len(selected_rs_list)
#selected_rs_list

# %% [markdown]
# ## Create the dataframe to hold the selected repeat stations database

# %%
# create the df
selected_df = df_rs_igrf.loc[df_rs_igrf['Code'].isin(selected_rs_list)]
selected_df = selected_df.reset_index()
selected_df = selected_df.drop(columns=["index"])

# Save it
selected_df.to_csv(output_folder / selected_rs_database_file, index=False, float_format="%.3f", na_rep="NaN")

# View it
selected_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Code                      447 non-null    object
#  1   Lat_dd                    447 non-null    float64
#  2   Lon_dd                    447 non-null    float64
#  3   Alt_m                     447 non-null    float64
#  4   Time_dy                   447 non-null    float64
#  5   D_dd                      447 non-null    float64
#  6   IGRF_D_dd                 447 non-null    float64
#  7   I_dd                      447 non-null    float64
#  8   IGRF_I_dd                 447 non-null    float64
#  9   F_nT                      447 non-null    float64
#  10  IGRF_F_nT                 447 non-null    float64
#  11  H_nT                      447 non-null    float64
#  12  IGRF_H_nT                 447 non-null    float64
#  13  X_nT                      447 non-null    float64
#  14  IGRF_X_nT                 447 non-null    float64
#  15  Calculated_X              447 non-null    float64
#  16  Y_nT                      424 non-null    float64
#  17  IGRF_Y_nT                 447 non-null    float64
#  18  Calculated_Y              447 non-null    float64
#  19  Z_nT                      424 non-null    float64
#  20  IGRF_Z_nT                 447 non-null    float64
#  21  Calculated_Z              447 non-null    float64
#  22  N_occupations             447 non-null    int64
#  23  Closest_OBS               447 non-null    object
#  24  TTB_distances_km          447 non-null    float64
#  25  VSS_distances_km          447 non-null    float64
#  26  State                     447 non-null    object
#  27  Region                    447 non-null    object
#  28  RS_name                   447 non-null    object
#  29  RMSE_D_Original_values    447 non-null    float64
#  30  RMSE_I_Original_values    447 non-null    float64
#  31  RMSE_F_Original_values    447 non-null    float64
#  32  RMSE_H_Original_values    447 non-null    float64
#  33  RMSE_X_Original_values    447 non-null    float64
#  34  RMSE_X_Calculated_values  447 non-null    float64
#  35  RMSE_Y_Original_values    444 non-null    float64
#  36  RMSE_Y_Calculated_values  447 non-null    float64
#  37  RMSE_Z_Original_values    444 non-null    float64
#  38  RMSE_Z_Calculated_values  447 non-null    float64
# dtypes: float64(33), int64(1), object(5)
# memory usage: 136.3+ KB

# %% [markdown]
# ## Create a sorted dataframe to hold the selected repeat stations database

# %%
selected_df
# Out:
#        Code  Lat_dd  Lon_dd    Alt_m   Time_dy    D_dd  IGRF_D_dd    I_dd  \
# 0    AC_CZS  -7.637 -72.670  182.464  1958.529   2.683      2.783  11.281
# 1    AC_CZS  -7.637 -72.670  182.464  1965.848   1.824      1.917  11.277
# 2    AC_CZS  -7.620 -72.670  195.600  1978.640  -0.035      0.150  11.026
# 3    AC_CZS  -7.599 -72.770  196.508  1986.279  -1.343     -1.083  10.685
# 4    AC_CZS  -7.599 -72.770  196.508  1989.503  -1.847     -1.633  10.468
# ..      ...     ...     ...      ...       ...     ...        ...     ...
# 442  RS_SMA -29.683 -53.823  107.905  1960.208  -6.616     -6.333 -26.516
# 443  RS_SMA -29.687 -53.835   90.518  1965.338  -7.381     -7.300 -27.114
# 444  RS_SMA -29.687 -53.835   90.518  1976.218  -9.126     -8.967 -28.829
# 445  RS_SMA -29.717 -53.700   85.200  1982.249 -10.361    -10.067 -30.357
# 446  RS_SMA -29.717 -53.700   85.200  1991.926 -11.670    -11.450 -32.479
#
#      IGRF_I_dd     F_nT  ...  RMSE_D_Original_values  RMSE_I_Original_values  \
# 0       11.167  29671.0  ...                   0.178                   0.204
# 1       10.917  29227.0  ...                   0.178                   0.204
# 2       10.800  28359.0  ...                   0.178                   0.204
# 3       10.550  27886.0  ...                   0.178                   0.204
# 4       10.317  27683.0  ...                   0.178                   0.204
# ..         ...      ...  ...                     ...                     ...
# 442    -26.533  24396.0  ...                   0.241                   0.197
# 443    -27.367  24200.0  ...                   0.241                   0.197
# 444    -29.067  23735.0  ...                   0.241                   0.197
# 445    -30.350  23521.0  ...                   0.241                   0.197
# 446    -32.383  23257.0  ...                   0.241                   0.197
#
#      RMSE_F_Original_values  RMSE_H_Original_values  RMSE_X_Original_values  \
# 0                    50.308                  36.257                  37.605
# 1                    50.308                  36.257                  37.605
# 2                    50.308                  36.257                  37.605
# 3                    50.308                  36.257                  37.605
# 4                    50.308                  36.257                  37.605
# ..                      ...                     ...                     ...
# 442                  51.595                  68.178                  69.163
# 443                  51.595                  68.178                  69.163
# 444                  51.595                  68.178                  69.163
# 445                  51.595                  68.178                  69.163
# 446                  51.595                  68.178                  69.163
#
#      RMSE_X_Calculated_values  RMSE_Y_Original_values  \
# 0                      37.680                  83.892
# 1                      37.680                  83.892
# 2                      37.680                  83.892
# 3                      37.680                  83.892
# 4                      37.680                  83.892
# ..                        ...                     ...
# 442                    69.214                  89.968
# 443                    69.214                  89.968
# 444                    69.214                  89.968
# 445                    69.214                  89.968
# 446                    69.214                  89.968
#
#      RMSE_Y_Calculated_values  RMSE_Z_Original_values  \
# 0                      84.130                 105.801
# 1                      84.130                 105.801
# 2                      84.130                 105.801
# 3                      84.130                 105.801
# 4                      84.130                 105.801
# ..                        ...                     ...
# 442                    90.235                  76.267
# 443                    90.235                  76.267
# 444                    90.235                  76.267
# 445                    90.235                  76.267
# 446                    90.235                  76.267
#
#      RMSE_Z_Calculated_values
# 0                     106.271
# 1                     106.271
# 2                     106.271
# 3                     106.271
# 4                     106.271
# ..                        ...
# 442                    75.942
# 443                    75.942
# 444                    75.942
# 445                    75.942
# 446                    75.942
#
# [447 rows x 39 columns]

# %%
table_df = selected_df.drop_duplicates(subset="Code", keep="last", inplace=False)
table_df = table_df.reset_index()
table_df = table_df.drop(columns = "index")
table_df
# Out:
#         Code  Lat_dd  Lon_dd     Alt_m   Time_dy    D_dd  IGRF_D_dd    I_dd  \
# 0     AC_CZS  -7.599 -72.770   196.508  1995.869  -2.901     -2.750   9.951
# 1     AC_RBC  -9.996 -67.802   136.304  2002.927  -6.048     -7.167   3.676
# 2     AM_BAR  -0.980 -62.922    31.832  2005.861 -12.522    -12.567  16.575
# 3     AM_BJC  -4.367 -70.050    73.160  1984.706  -3.858     -3.483  16.610
# 4     AM_CRA  -4.878 -66.895    75.256  1995.906  -7.881     -7.700  13.293
# 5     AM_MAN  -2.930 -59.975    90.700  2005.760 -14.324    -14.300  11.314
# 6   AM_MNC_A  -5.795 -61.278    41.728  2005.908 -12.694    -13.200   6.885
# 7     AM_SGC  -0.115 -66.992    94.148  2005.878 -10.434     -9.883  19.019
# 8     AP_MCP   0.052 -51.068    12.899  2009.536 -19.242    -18.983   6.739
# 9     AP_OPQ   3.861 -51.796    32.563  2009.527 -18.518    -18.417  13.810
# 10  BA_BAR_C -12.079 -45.002   709.739  2008.651 -22.191    -21.733 -21.238
# 11    BA_CRV -17.652 -39.249     7.880  2014.940 -23.793    -23.767 -37.160
# 12    BA_SAL -12.902 -38.327    13.998  2006.582 -23.044    -23.167 -29.050
# 13    BA_VCQ -14.866 -40.859   906.908  2006.574 -22.823    -22.850 -28.842
# 14    CE_FOR  -3.878 -38.426    24.395  2014.686 -21.403    -21.283 -17.881
# 15    ES_CIP -20.836 -41.188   106.349  2014.954 -23.398    -23.317 -38.876
# 16    GO_FOR -15.540 -47.355   946.420  1985.114 -18.322    -18.350 -16.274
# 17    GO_GOI -16.631 -49.228   736.682  2001.411 -19.184    -19.050 -21.274
# 18    MA_CAR  -7.317 -47.442   175.444  1993.727 -19.572    -19.517  -4.991
# 19    MA_SLZ  -2.581 -44.239    41.712  2003.734 -20.892    -20.800  -4.058
# 20    MG_MTC -16.722 -43.803   657.570  1989.380 -20.559    -20.567 -22.874
# 21    MG_PCA -21.787 -46.590  1253.964  2017.911 -21.548    -21.550 -35.913
# 22    MG_UBR -19.767 -47.963   797.527  1996.223 -18.552    -18.750 -25.409
# 23    MS_COR -19.012 -57.662   147.915  2001.762 -13.088    -13.050 -17.770
# 24    MS_PPO -22.552 -55.705   651.116  2006.847 -14.414    -14.467 -25.615
# 25    MS_TLG -20.756 -51.688   327.278  2002.738 -17.016    -17.100 -25.106
# 26    MT_AFT  -9.871 -56.106   275.495  2019.757 -18.226    -18.067 -10.050
# 27    MT_CUI -15.657 -56.123   184.181  1975.515 -10.710    -10.533  -6.914
# 28    MT_GNT -13.154 -53.253   380.906  2007.562  -7.983    -17.883 -13.317
# 29    MT_GUI -16.352 -53.755   482.920  1974.697 -12.229    -12.133  -9.454
# 30    MT_SFA -11.629 -50.696   197.822  2007.559 -19.300    -19.350 -13.483
# 31  PA_ALT_C  -3.255 -52.247   113.534  2019.727 -19.554    -19.467  -2.461
# 32    PA_JAC  -6.234 -57.775    97.460  2004.446 -15.274    -15.267   3.878
# 33    PA_MRB  -5.368 -49.138   102.667  2003.709 -19.663    -19.633  -3.267
# 34    PA_PTR  -1.487 -56.491    54.854  2005.785 -16.594    -16.400  10.165
# 35    PA_SAN  -2.422 -54.785    28.660  2019.737 -18.640    -18.483   1.892
# 36    PA_SFX  -6.664 -51.963   201.572  2007.548 -18.874    -18.800  -3.874
# 37    PA_VSU  -1.198 -46.199    28.512  2019.702 -20.455    -20.417  -5.831
# 38    PE_FNH  -3.850 -32.417    56.580  1988.170 -21.166    -21.633 -18.111
# 39    PE_PET  -9.365 -40.565   384.490  2014.910 -22.720    -22.567 -24.578
# 40    PE_REC  -8.080 -34.895     1.120  2001.326 -22.496    -22.517 -24.027
# 41    PI_FLO  -6.846 -43.077   193.330  2003.912 -21.603    -21.567 -13.342
# 42    PR_CUR -25.525 -49.182   898.580  2007.754 -19.525    -18.217 -35.475
# 43    PR_FIG -25.595 -54.492   222.528  2008.894 -14.633    -14.783 -31.121
# 44    RO_JIP -10.877 -61.850   169.140  2006.874 -12.654    -12.283  -3.300
# 45    RO_PVL  -8.709 -63.895    88.210  2006.872 -11.327    -11.083   4.037
# 46    RO_VLN -12.686 -60.094   611.352  2006.883 -13.151    -13.300  -6.513
# 47    RR_BOV   2.839 -60.689    80.640  2005.755 -14.828    -14.217  21.404
# 48    RS_PAL -29.992 -51.163     8.212  2007.789 -15.494    -15.400 -37.519
# 49    RS_SMA -29.717 -53.700    85.200  1991.926 -11.670    -11.450 -32.479
#
#     IGRF_I_dd     F_nT  ...  RMSE_D_Original_values  RMSE_I_Original_values  \
# 0       9.833  27342.0  ...                   0.178                   0.204
# 1       3.667  25681.0  ...                   0.560                   0.291
# 2      16.583  28071.0  ...                   0.163                   0.222
# 3      16.567  28921.0  ...                   0.245                   0.263
# 4      13.617  27632.0  ...                   0.222                   0.236
# 5      11.133  27065.0  ...                   0.327                   0.208
# 6       7.033  25926.0  ...                   0.506                   0.148
# 7      20.267  28735.0  ...                   0.592                   0.677
# 8       6.550  27225.0  ...                   0.255                   0.272
# 9      14.067  28598.0  ...                   0.104                   0.240
# 10    -21.217  24323.0  ...                   0.267                   0.110
# 11    -37.200  24032.0  ...                   0.119                   0.152
# 12    -29.083  24416.0  ...                   0.217                   0.207
# 13    -29.067  24240.0  ...                   0.091                   0.147
# 14    -17.783  26311.0  ...                   0.149                   0.293
# 15    -38.867  23555.0  ...                   0.095                   0.076
# 16    -16.067  24192.0  ...                   0.067                   0.255
# 17    -21.117  23629.0  ...                   0.105                   0.181
# 18     -5.067  25608.0  ...                   0.132                   0.126
# 19     -4.083  26329.0  ...                   0.279                   0.228
# 20    -22.767  24014.0  ...                   0.050                   0.138
# 21    -36.067  23079.0  ...                   0.128                   0.264
# 22    -25.250  23349.0  ...                   0.233                   0.251
# 23    -17.550  23356.0  ...                   0.122                   0.247
# 24    -25.483  22846.0  ...                   0.064                   0.276
# 25    -25.183  23104.0  ...                   0.081                   0.184
# 26     -9.900  24146.0  ...                   0.152                   0.169
# 27     -6.833  24810.0  ...                   0.154                   0.159
# 28    -13.567  23807.0  ...                   9.900                   0.250
# 29     -9.283  24499.0  ...                   0.109                   0.152
# 30    -13.717  24196.0  ...                   0.087                   0.181
# 31     -2.483  25792.0  ...                   0.156                   0.426
# 32      3.817  25775.0  ...                   0.038                   0.154
# 33     -3.250  25651.0  ...                   0.200                   0.044
# 34     10.650  27356.0  ...                   0.163                   0.421
# 35      1.917  26150.0  ...                   0.305                   0.104
# 36     -3.750  25265.0  ...                   0.074                   0.124
# 37     -5.917  26446.0  ...                   0.038                   0.086
# 38    -14.383  26750.0  ...                   0.452                   1.850
# 39    -24.633  25079.0  ...                   0.216                   0.346
# 40    -23.800  25916.0  ...                   0.273                   0.455
# 41    -13.117  25391.0  ...                   0.126                   0.178
# 42    -34.567  23169.0  ...                   0.747                   0.635
# 43    -30.817  22579.0  ...                   0.239                   0.320
# 44     -1.917  24219.0  ...                   0.506                   1.321
# 45      3.333  25470.0  ...                   0.252                   0.471
# 46     -6.417  24126.0  ...                   0.086                   0.126
# 47     21.383  29552.0  ...                   0.500                   0.452
# 48    -37.617  22937.0  ...                   0.144                   0.206
# 49    -32.383  23257.0  ...                   0.241                   0.197
#
#     RMSE_F_Original_values  RMSE_H_Original_values  RMSE_X_Original_values  \
# 0                   50.308                  36.257                  37.605
# 1                   86.356                  86.354                  94.392
# 2                  130.192                  72.745                7435.109
# 3                   62.099                  42.024                  43.905
# 4                   31.757                  44.168                  41.469
# 5                  128.662                 133.015                4074.033
# 6                  191.700                 182.200               22128.100
# 7                  412.539                 384.585                7568.770
# 8                   86.898                  98.288                9125.755
# 9                   50.522                  28.261                9762.055
# 10                  52.255                  59.628               17229.949
# 11                  54.539                  45.058                  50.529
# 12                 255.664                 238.185                7470.992
# 13                  60.531                  74.781               11023.646
# 14                 256.376                 218.821                8405.460
# 15                  47.918                  46.367                  48.542
# 16                  45.636                  54.395                  54.910
# 17                  61.833                  62.583                  62.222
# 18                  56.300                  58.012                  49.264
# 19                 140.384                 108.482                 129.210
# 20                  64.418                  74.008                  71.733
# 21                  82.403                  90.569                  75.698
# 22                 152.076                 163.954                 160.095
# 23                  74.252                  73.321                  73.968
# 24                  58.744                  56.249                9414.663
# 25                  75.006                  81.767                  81.018
# 26                  25.431                  19.090                   6.233
# 27                 105.813                 104.857                  98.110
# 28                  61.000                  34.300               27564.700
# 29                  23.993                  31.023                  37.187
# 30                  65.901                  71.945               16051.774
# 31                  60.391                  51.011                  55.079
# 32                  32.121                  38.176                  37.152
# 33                  63.089                  62.652                  70.279
# 34                  99.617                 140.222               14737.005
# 35                 177.699                 158.689                 151.594
# 36                  26.500                  28.200               25578.200
# 37                   4.100                2991.000                   2.900
# 38                 360.092                 431.915                 436.326
# 39                 118.414                 124.165                7446.796
# 40                 242.159                 228.651                 247.253
# 41                  71.700                  73.719                  82.331
# 42                 175.553                 131.757                9036.790
# 43                 117.606                 109.025                8139.482
# 44                 425.610                 427.419               11394.632
# 45                 113.491                  83.600                5765.877
# 46                  41.308                  41.893                9218.669
# 47                 309.836                 229.880                4752.690
# 48                 132.193                 125.419                7398.539
# 49                  51.595                  68.178                  69.163
#
#     RMSE_X_Calculated_values  RMSE_Y_Original_values  \
# 0                     37.680                  83.892
# 1                     94.667                 259.678
# 2                     72.709                  91.531
# 3                     43.974                 119.560
# 4                     41.376                 106.824
# 5                     97.073                 171.983
# 6                    126.184                     NaN
# 7                    393.817                 281.119
# 8                     84.635                 133.252
# 9                     33.715                  48.235
# 10                    58.483                  27.642
# 11                    50.676                  44.040
# 12                   205.180                 153.745
# 13                    79.215                  29.297
# 14                   210.853                  89.590
# 15                    48.334                  32.528
# 16                    54.479                  27.365
# 17                    62.018                  45.352
# 18                    49.562                  69.645
# 19                   129.419                 120.217
# 20                    71.065                  28.001
# 21                    75.892                  70.044
# 22                   159.925                 104.993
# 23                    73.911                  53.195
# 24                    56.220                  25.873
# 25                    80.763                  34.090
# 26                     6.101                  65.490
# 27                    98.502                  78.311
# 28                   861.641                     NaN
# 29                    36.505                  44.354
# 30                    78.120                  26.922
# 31                    55.204                  71.786
# 32                    36.640                  18.752
# 33                    70.466                  95.073
# 34                   113.415                  84.100
# 35                   151.369                 162.109
# 36                    39.268                     NaN
# 37                     2.192                  17.300
# 38                   436.222                 207.599
# 39                   111.813                 115.292
# 40                   247.749                  90.339
# 41                    82.304                  47.641
# 42                   165.080                 213.737
# 43                   105.577                  93.829
# 44                   451.554                 189.229
# 45                    75.883                 125.530
# 46                    38.723                  36.241
# 47                   204.150                 265.957
# 48                   119.215                  66.193
# 49                    69.214                  89.968
#
#     RMSE_Y_Calculated_values  RMSE_Z_Original_values  RMSE_Z_Calculated_values
# 0                     84.130                 105.801                   106.271
# 1                    259.546                 141.101                   141.442
# 2                     83.793                 184.312                   168.085
# 3                    119.754                 149.236                   149.702
# 4                    107.543                 110.291                   109.858
# 5                    168.497                 143.647                   141.949
# 6                    264.399                     NaN                    89.371
# 7                    281.445                 277.701                   371.984
# 8                    131.661                 136.266                   130.428
# 9                     47.904                 127.523                   128.145
# 10                   106.645                  43.305                    38.480
# 11                    43.858                  72.464                    72.712
# 12                   152.278                 131.621                   131.736
# 13                    28.760                  41.318                    44.338
# 14                    90.133                 207.923                   200.064
# 15                    32.951                  34.182                    34.192
# 16                    27.726                 105.511                   105.989
# 17                    45.207                  78.663                    78.976
# 18                    69.950                  58.890                    58.525
# 19                   120.172                 148.660                   148.801
# 20                    27.506                  46.177                    46.441
# 21                    70.342                 102.036                   101.799
# 22                   104.836                  88.462                    88.822
# 23                    53.569                 110.829                   111.251
# 24                    24.690                 118.176                   115.778
# 25                    33.882                  71.991                    72.335
# 26                    66.123                  76.460                    76.915
# 27                    78.590                  74.459                    74.443
# 28                  3906.206                     NaN                   118.132
# 29                    45.223                  63.177                    63.553
# 30                    21.914                  58.584                    71.387
# 31                    71.469                 225.208                   204.595
# 32                    18.314                  67.871                    68.397
# 33                    94.945                  22.080                    22.120
# 34                   115.012                 152.100                   181.505
# 35                   161.763                  98.130                    97.864
# 36                    22.451                     NaN                    49.668
# 37                    17.606                  39.000                    39.230
# 38                   207.545                 835.244                   835.346
# 39                   113.094                 157.034                   152.981
# 40                    90.363                 229.012                   229.354
# 41                    47.983                  79.506                    79.578
# 42                   239.630                 255.235                   283.809
# 43                    92.087                 144.670                   140.925
# 44                   171.575                 577.208                   575.791
# 45                   125.751                 232.403                   238.988
# 46                    39.838                  56.192                    54.680
# 47                   271.670                 359.013                   342.780
# 48                    66.305                 102.888                   100.978
# 49                    90.235                  76.267                    75.942
#
# [50 rows x 39 columns]

# %%
table_df.to_csv(output_folder / selected_database_table_ref, index=False, float_format="%.3f", na_rep="NaN")
