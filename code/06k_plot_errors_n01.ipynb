# %% [markdown]
# # Plot the errors for each occupation group: n 01
#
# ## Description
#
# This program does the following using the Repeat station and IGRF error database:
# - It reads the file with the dataframe from the n occupation stations group
# - It plots the RMSE, Mean NRMSE and Std NRMSE values for each group

# %%
# Import modules
import mestrado_module as mm
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pathlib import Path

# %%
## Define the minimum number of occupations a station must have (n), it is a cut out value
n1 = 1
n2 = 2

# File with the chosen n repeat stations
errors_df_folder: Path = Path(mm.path_pipeline_04_igrf_calc)
errors_df_file: Path = Path(mm.output_4d_code_error_database)

# Save figures files
output_folder: Path = Path(mm.path_pipeline_06f_temporal_series_n01)

# Figure style
sns.set_style("darkgrid")

# %%
# Save figures files for rmse

## Group 1
g1_fig_rmse_f: Path = Path("00_g1_rmse_f_plot_n_01.png")
g1_fig_rmse_h: Path = Path("00_g1_rmse_h_plot_n_01.png")
g1_fig_rmse_x: Path = Path("00_g1_rmse_x_plot_n_01.png")
g1_fig_rmse_y: Path = Path("00_g1_rmse_y_plot_n_01.png")
g1_fig_rmse_z: Path = Path("00_g1_rmse_z_plot_n_01.png")
g1_fig_rmse_d: Path = Path("00_g1_rmse_d_plot_n_01.png")
g1_fig_rmse_i: Path = Path("00_g1_rmse_i_plot_n_01.png")

## Group 2
g2_fig_rmse_f: Path = Path("00_g2_rmse_f_plot_n_01.png")
g2_fig_rmse_h: Path = Path("00_g2_rmse_h_plot_n_01.png")
g2_fig_rmse_x: Path = Path("00_g2_rmse_x_plot_n_01.png")
g2_fig_rmse_y: Path = Path("00_g2_rmse_y_plot_n_01.png")
g2_fig_rmse_z: Path = Path("00_g2_rmse_z_plot_n_01.png")
g2_fig_rmse_d: Path = Path("00_g2_rmse_d_plot_n_01.png")
g2_fig_rmse_i: Path = Path("00_g2_rmse_i_plot_n_01.png")

# Group 3
g3_fig_rmse_f: Path = Path("00_g3_rmse_f_plot_n_01.png")
g3_fig_rmse_h: Path = Path("00_g3_rmse_h_plot_n_01.png")
g3_fig_rmse_x: Path = Path("00_g3_rmse_x_plot_n_01.png")
g3_fig_rmse_y: Path = Path("00_g3_rmse_y_plot_n_01.png")
g3_fig_rmse_z: Path = Path("00_g3_rmse_z_plot_n_01.png")
g3_fig_rmse_d: Path = Path("00_g3_rmse_d_plot_n_01.png")
g3_fig_rmse_i: Path = Path("00_g3_rmse_i_plot_n_01.png")

# Group 4
g4_fig_rmse_f: Path = Path("00_g4_rmse_f_plot_n_01.png")
g4_fig_rmse_h: Path = Path("00_g4_rmse_h_plot_n_01.png")
g4_fig_rmse_x: Path = Path("00_g4_rmse_x_plot_n_01.png")
g4_fig_rmse_y: Path = Path("00_g4_rmse_y_plot_n_01.png")
g4_fig_rmse_z: Path = Path("00_g4_rmse_z_plot_n_01.png")
g4_fig_rmse_d: Path = Path("00_g4_rmse_d_plot_n_01.png")
g4_fig_rmse_i: Path = Path("00_g4_rmse_i_plot_n_01.png")

# Group 5
g5_fig_rmse_f: Path = Path("00_g5_rmse_f_plot_n_01.png")
g5_fig_rmse_h: Path = Path("00_g5_rmse_h_plot_n_01.png")
g5_fig_rmse_x: Path = Path("00_g5_rmse_x_plot_n_01.png")
g5_fig_rmse_y: Path = Path("00_g5_rmse_y_plot_n_01.png")
g5_fig_rmse_z: Path = Path("00_g5_rmse_z_plot_n_01.png")
g5_fig_rmse_d: Path = Path("00_g5_rmse_d_plot_n_01.png")
g5_fig_rmse_i: Path = Path("00_g5_rmse_i_plot_n_01.png")

# %% [markdown]
# ## Read the data

# %%
df = pd.read_csv(errors_df_folder / errors_df_file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Code                      218 non-null    object
#  1   N_occupations             218 non-null    int64
#  2   RMSE_D_Original_values    218 non-null    float64
#  3   RMSE_I_Original_values    218 non-null    float64
#  4   RMSE_F_Original_values    218 non-null    float64
#  5   RMSE_H_Original_values    218 non-null    float64
#  6   RMSE_X_Original_values    218 non-null    float64
#  7   RMSE_X_Calculated_values  218 non-null    float64
#  8   RMSE_Y_Original_values    195 non-null    float64
#  9   RMSE_Y_Calculated_values  218 non-null    float64
#  10  RMSE_Z_Original_values    195 non-null    float64
#  11  RMSE_Z_Calculated_values  218 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 20.6+ KB

# %% [markdown]
# ## Plot the temporal series for each station in this n group

# %%
# Define variables
component_f = "Total Field"
component_h = "Horizontal Field"
component_x = "X Field"
component_y = "Y Field"
component_z = "Z Field"
component_d = "Declination Field"
component_i = "Inclination Field"

# Original
orig_symbol = "o"
orig_color = "blue"
orig_label = "Station original value"
orig_linestyle = '-'

# Calculated
calc_symbol = "+"
calc_color = "red"
calc_label = "Station calculated value"
calc_linestyle = "--"

# IGRF
igrf_symbol = "d"
igrf_color = "green"
igrf_label = "IGRF13"
igrf_linestyle = "-."

# General
axis_label_fsize = 14
title_fontsize = 16
tick_size = 14
legend_loc = "best"
dpi_quality = 300
value_bbox_inches = "tight"
fill_color = "purple"

# %%
# Auxiliar df
aux_df = df.loc[df["N_occupations"].between(n1,n2)]
aux_df = aux_df.reset_index()

# %%
# Define intervals
int0 = 0
int1 = 20
int2 = 21
int3 = 40
int4 = 41
int5 = 60
int6 = 61
int7 = 80
int8 = 81
int9 = 92

# %%
# Group
g1_df = aux_df.loc[int0:int1]
g2_df = aux_df.loc[int2:int3]
g3_df = aux_df.loc[int4:int5]
g4_df = aux_df.loc[int6:int7]
g5_df = aux_df.loc[int8:int9]

#view
g1_df
# Out:
#     index      Code  N_occupations  RMSE_D_Original_values  \
# 0       1    AC_EPC              2                   0.065
# 1       2  AC_EPC_B              1                   0.136
# 2       5  AL_RLO_A              1                   0.102
# 3       8  AM_COD_A              1                   0.037
# 4      11  AM_JUT_A              1                   0.217
# 5      13  AM_MAU_A              1                   0.141
# 6      14  AM_MNC_A              1                   0.506
# 7      19  AP_AMP_A              2                   0.565
# 8      24  BA_BAR_B              1                   0.002
# 9      27  BA_BRG_B              1                   0.000
# 10     31    BA_FST              1                   0.394
# 11     35    BA_SCC              2                   0.063
# 12     37  BA_VLC_A              1                   0.224
# 13     38    CE_ACU              1                   0.040
# 14     40    CE_CTE              2                   0.110
# 15     43    ES_CBR              1                   0.157
# 16     46    GO_ARA              1                   0.094
# 17     48  GO_ARA_B              1                   0.124
# 18     49  GO_ARA_C              2                   0.035
# 19     50  GO_ARU_A              1                   0.037
# 20     52  GO_ARU_C              2                   0.069
#
#     RMSE_I_Original_values  RMSE_F_Original_values  RMSE_H_Original_values  \
# 0                    0.024                  78.275                  78.164
# 1                    1.312                  69.800                  69.000
# 2                    0.151                  41.100                   0.900
# 3                    0.147                  97.700                 108.800
# 4                   31.237                 209.400                 171.400
# 5                   17.060                  79.300                  65.400
# 6                    0.148                 191.700                 182.200
# 7                    0.114                  73.858                  62.638
# 8                    0.170                   1.200                  17.900
# 9                    0.314                 171.300                 159.500
# 10                   0.548                  86.800                  28.100
# 11                   0.139                  18.078                  46.670
# 12                   0.030                  66.200                  46.600
# 13                   0.063                  61.900                  56.700
# 14                   0.171                  49.285                  47.585
# 15                   0.108                  10.300                  36.100
# 16                   0.292                  24.300                  63.800
# 17                   0.095                  30.900                  23.600
# 18                   0.112                  34.529                  43.209
# 19                   0.016                  55.500                  54.800
# 20                   0.066                  32.046                  36.167
#
#     RMSE_X_Original_values  RMSE_X_Calculated_values  RMSE_Y_Original_values  \
# 0                   80.022                    80.937                  19.965
# 1                24291.700                    84.170                     NaN
# 2                   16.200                    16.159                  36.400
# 3                20519.800                   110.024                     NaN
# 4                18956.400                   186.835                     NaN
# 5                21378.700                    45.550                     NaN
# 6                22128.100                   126.184                     NaN
# 7                  112.021                   112.403                 272.111
# 8                   17.200                    16.756                   3.800
# 9                  157.000                   157.282                  27.300
# 10                  85.000                    84.850                 127.800
# 11               22436.428                    36.057                  14.900
# 12                  10.000                    11.036                  94.100
# 13                  60.200                    59.380                   1.300
# 14                  40.635                    40.036                  52.573
# 15               31701.600                    11.024                     NaN
# 16               29261.500                    45.384                     NaN
# 17                   7.100                     7.721                  54.600
# 18                  36.426                    37.024                  26.803
# 19                  56.700                    56.880                  11.800
# 20                  28.264                    28.953                  34.296
#
#     RMSE_Y_Calculated_values  RMSE_Z_Original_values  RMSE_Z_Calculated_values
# 0                     19.307                   8.365                     7.956
# 1                     47.852                     NaN                   577.241
# 2                     36.989                  81.600                    81.556
# 3                      7.771                     NaN                    48.080
# 4                     72.115                     NaN                 14876.953
# 5                     77.803                     NaN                  7917.534
# 6                    264.399                     NaN                    89.371
# 7                    271.717                  75.217                    76.014
# 8                      3.604                  70.300                    70.492
# 9                     28.136                 163.300                   163.391
# 10                   128.355                 247.800                   248.159
# 11                    36.160                   9.600                    40.587
# 12                    94.457                  48.200                    48.427
# 13                     1.138                  41.600                    41.096
# 14                    52.072                  80.653                    80.620
# 15                    65.108                     NaN                    32.973
# 16                    60.630                     NaN                   104.979
# 17                    55.014                  47.400                    48.349
# 18                    27.227                  39.375                    39.075
# 19                    11.585                   9.100                     9.172
# 20                    34.661                  18.439                    18.028

# %% [markdown]
# ## Plot the RMSE

# %% [markdown]
# ### Group 1

# %%
# F field info for plot
rmse_f = g1_df["RMSE_F_Original_values"]
station_name = g1_df["Code"]
# Figure
fig1, ax1 = plt.subplots()
ax1.scatter(station_name, rmse_f, marker = orig_symbol)
ax1.set_xlabel("Station name", fontsize=axis_label_fsize)
ax1.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax1.set_title(f"{component_f}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g1_fig_rmse_f, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# H field info for plot
rmse_h = g1_df["RMSE_H_Original_values"]
station_name = g1_df["Code"]
# Figure
fig2, ax2 = plt.subplots()
ax2.scatter(station_name, rmse_h, marker = orig_symbol)
ax2.set_xlabel("Station name", fontsize=axis_label_fsize)
ax2.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax2.set_title(f"{component_h}: Group with {n1} or {n2} more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g1_fig_rmse_h, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# X field info for plot
rmse_x_orig = g1_df["RMSE_X_Original_values"]
rmse_x_calc = g1_df["RMSE_X_Calculated_values"]
station_name = g1_df["Code"]
# Figure
fig3, ax3 = plt.subplots()
ax3.scatter(station_name, rmse_x_orig, marker = orig_symbol)
ax3.scatter(station_name, rmse_x_calc, marker = calc_symbol) 
ax3.set_xlabel("Station name", fontsize=axis_label_fsize)
ax3.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax3.set_title(f"{component_x}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g1_fig_rmse_x, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# Y field info for plot
rmse_y_orig = g1_df["RMSE_Y_Original_values"]
rmse_y_calc = g1_df["RMSE_Y_Calculated_values"]
station_name = g1_df["Code"]
# Figure
fig4, ax4 = plt.subplots()
ax4.scatter(station_name, rmse_y_orig, marker = orig_symbol)
ax4.scatter(station_name, rmse_y_calc, marker = "+")
ax4.set_xlabel("Station name", fontsize=axis_label_fsize)
ax4.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax4.set_title(f"{component_y}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g1_fig_rmse_y, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# Z field info for plot
rmse_z_orig = g1_df["RMSE_Z_Original_values"]
rmse_z_calc = g1_df["RMSE_Z_Calculated_values"]
station_name = g1_df["Code"]
# Figure
fig4, ax5 = plt.subplots()
ax5.scatter(station_name, rmse_z_orig, marker = orig_symbol)
ax5.scatter(station_name, rmse_z_calc, marker = "+")
ax5.set_xlabel("Station name", fontsize=axis_label_fsize)
ax5.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax5.set_title(f"{component_z}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g1_fig_rmse_z, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# D field info for plot
rmse_d = g1_df["RMSE_D_Original_values"]
station_name = g1_df["Code"]
# Figure
fig6, ax6 = plt.subplots()
ax6.scatter(station_name, rmse_d, marker = orig_symbol)
ax6.set_xlabel("Station name", fontsize=axis_label_fsize)
ax6.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax6.set_title(f"{component_d}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g1_fig_rmse_d, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# I field info for plot
rmse_i = g1_df["RMSE_I_Original_values"]
station_name = g1_df["Code"]
# Figure
fig7, ax7 = plt.subplots()
ax7.scatter(station_name, rmse_i, marker = orig_symbol)
ax7.set_xlabel("Station name", fontsize=axis_label_fsize)
ax7.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax7.set_title(f"{component_i}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g1_fig_rmse_i, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %% [markdown]
# ## Group 2

# %%
# F field info for plot
rmse_f = g2_df["RMSE_F_Original_values"]
station_name = g2_df["Code"]
# Figure
fig1, ax1 = plt.subplots()
ax1.scatter(station_name, rmse_f, marker = orig_symbol)
ax1.set_xlabel("Station name", fontsize=axis_label_fsize)
ax1.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax1.set_title(f"{component_f}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g2_fig_rmse_f, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# H field info for plot
rmse_h = g2_df["RMSE_H_Original_values"]
station_name = g2_df["Code"]
# Figure
fig2, ax2 = plt.subplots()
ax2.scatter(station_name, rmse_h, marker = orig_symbol)
ax2.set_xlabel("Station name", fontsize=axis_label_fsize)
ax2.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax2.set_title(f"{component_h}: Group with {n1} or {n2} more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g2_fig_rmse_h, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# X field info for plot
rmse_x_orig = g2_df["RMSE_X_Original_values"]
rmse_x_calc = g2_df["RMSE_X_Calculated_values"]
station_name = g2_df["Code"]
# Figure
fig3, ax3 = plt.subplots()
ax3.scatter(station_name, rmse_x_orig, marker = orig_symbol)
ax3.scatter(station_name, rmse_x_calc, marker = calc_symbol) 
ax3.set_xlabel("Station name", fontsize=axis_label_fsize)
ax3.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax3.set_title(f"{component_x}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g2_fig_rmse_x, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# Y field info for plot
rmse_y_orig = g2_df["RMSE_Y_Original_values"]
rmse_y_calc = g2_df["RMSE_Y_Calculated_values"]
station_name = g2_df["Code"]
# Figure
fig4, ax4 = plt.subplots()
ax4.scatter(station_name, rmse_y_orig, marker = orig_symbol)
ax4.scatter(station_name, rmse_y_calc, marker = "+")
ax4.set_xlabel("Station name", fontsize=axis_label_fsize)
ax4.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax4.set_title(f"{component_y}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g2_fig_rmse_y, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# Z field info for plot
rmse_z_orig = g2_df["RMSE_Z_Original_values"]
rmse_z_calc = g2_df["RMSE_Z_Calculated_values"]
station_name = g2_df["Code"]
# Figure
fig4, ax5 = plt.subplots()
ax5.scatter(station_name, rmse_z_orig, marker = orig_symbol)
ax5.scatter(station_name, rmse_z_calc, marker = "+")
ax5.set_xlabel("Station name", fontsize=axis_label_fsize)
ax5.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax5.set_title(f"{component_z}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g2_fig_rmse_z, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# D field info for plot
rmse_d = g2_df["RMSE_D_Original_values"]
station_name = g2_df["Code"]
# Figure
fig6, ax6 = plt.subplots()
ax6.scatter(station_name, rmse_d, marker = orig_symbol)
ax6.set_xlabel("Station name", fontsize=axis_label_fsize)
ax6.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax6.set_title(f"{component_d}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g2_fig_rmse_d, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# I field info for plot
rmse_i = g2_df["RMSE_I_Original_values"]
station_name = g2_df["Code"]
# Figure
fig7, ax7 = plt.subplots()
ax7.scatter(station_name, rmse_i, marker = orig_symbol)
ax7.set_xlabel("Station name", fontsize=axis_label_fsize)
ax7.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax7.set_title(f"{component_i}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g2_fig_rmse_i, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %% [markdown]
# ## Group 3

# %%
# F field info for plot
rmse_f = g3_df["RMSE_F_Original_values"]
station_name = g3_df["Code"]
# Figure
fig1, ax1 = plt.subplots()
ax1.scatter(station_name, rmse_f, marker = orig_symbol)
ax1.set_xlabel("Station name", fontsize=axis_label_fsize)
ax1.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax1.set_title(f"{component_f}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g3_fig_rmse_f, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# H field info for plot
rmse_h = g3_df["RMSE_H_Original_values"]
station_name = g3_df["Code"]
# Figure
fig2, ax2 = plt.subplots()
ax2.scatter(station_name, rmse_h, marker = orig_symbol)
ax2.set_xlabel("Station name", fontsize=axis_label_fsize)
ax2.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax2.set_title(f"{component_h}: Group with {n1} or {n2} more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g3_fig_rmse_h, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# X field info for plot
rmse_x_orig = g3_df["RMSE_X_Original_values"]
rmse_x_calc = g3_df["RMSE_X_Calculated_values"]
station_name = g3_df["Code"]
# Figure
fig3, ax3 = plt.subplots()
ax3.scatter(station_name, rmse_x_orig, marker = orig_symbol)
ax3.scatter(station_name, rmse_x_calc, marker = calc_symbol) 
ax3.set_xlabel("Station name", fontsize=axis_label_fsize)
ax3.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax3.set_title(f"{component_x}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g3_fig_rmse_x, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# Y field info for plot
rmse_y_orig = g3_df["RMSE_Y_Original_values"]
rmse_y_calc = g3_df["RMSE_Y_Calculated_values"]
station_name = g3_df["Code"]
# Figure
fig4, ax4 = plt.subplots()
ax4.scatter(station_name, rmse_y_orig, marker = orig_symbol)
ax4.scatter(station_name, rmse_y_calc, marker = "+")
ax4.set_xlabel("Station name", fontsize=axis_label_fsize)
ax4.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax4.set_title(f"{component_y}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g3_fig_rmse_y, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# Z field info for plot
rmse_z_orig = g3_df["RMSE_Z_Original_values"]
rmse_z_calc = g3_df["RMSE_Z_Calculated_values"]
station_name = g3_df["Code"]
# Figure
fig4, ax5 = plt.subplots()
ax5.scatter(station_name, rmse_z_orig, marker = orig_symbol)
ax5.scatter(station_name, rmse_z_calc, marker = "+")
ax5.set_xlabel("Station name", fontsize=axis_label_fsize)
ax5.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax5.set_title(f"{component_z}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g3_fig_rmse_z, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# D field info for plot
rmse_d = g3_df["RMSE_D_Original_values"]
station_name = g3_df["Code"]
# Figure
fig6, ax6 = plt.subplots()
ax6.scatter(station_name, rmse_d, marker = orig_symbol)
ax6.set_xlabel("Station name", fontsize=axis_label_fsize)
ax6.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax6.set_title(f"{component_d}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g3_fig_rmse_d, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# I field info for plot
rmse_i = g3_df["RMSE_I_Original_values"]
station_name = g3_df["Code"]
# Figure
fig7, ax7 = plt.subplots()
ax7.scatter(station_name, rmse_i, marker = orig_symbol)
ax7.set_xlabel("Station name", fontsize=axis_label_fsize)
ax7.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax7.set_title(f"{component_i}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g3_fig_rmse_i, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %% [markdown]
# ## Group 4

# %%
# F field info for plot
rmse_f = g4_df["RMSE_F_Original_values"]
station_name = g4_df["Code"]
# Figure
fig1, ax1 = plt.subplots()
ax1.scatter(station_name, rmse_f, marker = orig_symbol)
ax1.set_xlabel("Station name", fontsize=axis_label_fsize)
ax1.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax1.set_title(f"{component_f}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g4_fig_rmse_f, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# H field info for plot
rmse_h = g4_df["RMSE_H_Original_values"]
station_name = g4_df["Code"]
# Figure
fig2, ax2 = plt.subplots()
ax2.scatter(station_name, rmse_h, marker = orig_symbol)
ax2.set_xlabel("Station name", fontsize=axis_label_fsize)
ax2.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax2.set_title(f"{component_h}: Group with {n1} or {n2} more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g4_fig_rmse_h, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# X field info for plot
rmse_x_orig = g4_df["RMSE_X_Original_values"]
rmse_x_calc = g4_df["RMSE_X_Calculated_values"]
station_name = g4_df["Code"]
# Figure
fig3, ax3 = plt.subplots()
ax3.scatter(station_name, rmse_x_orig, marker = orig_symbol)
ax3.scatter(station_name, rmse_x_calc, marker = calc_symbol) 
ax3.set_xlabel("Station name", fontsize=axis_label_fsize)
ax3.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax3.set_title(f"{component_x}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g4_fig_rmse_x, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# Y field info for plot
rmse_y_orig = g4_df["RMSE_Y_Original_values"]
rmse_y_calc = g4_df["RMSE_Y_Calculated_values"]
station_name = g4_df["Code"]
# Figure
fig4, ax4 = plt.subplots()
ax4.scatter(station_name, rmse_y_orig, marker = orig_symbol)
ax4.scatter(station_name, rmse_y_calc, marker = "+")
ax4.set_xlabel("Station name", fontsize=axis_label_fsize)
ax4.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax4.set_title(f"{component_y}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g4_fig_rmse_y, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# Z field info for plot
rmse_z_orig = g4_df["RMSE_Z_Original_values"]
rmse_z_calc = g4_df["RMSE_Z_Calculated_values"]
station_name = g4_df["Code"]
# Figure
fig4, ax5 = plt.subplots()
ax5.scatter(station_name, rmse_z_orig, marker = orig_symbol)
ax5.scatter(station_name, rmse_z_calc, marker = "+")
ax5.set_xlabel("Station name", fontsize=axis_label_fsize)
ax5.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax5.set_title(f"{component_z}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g4_fig_rmse_z, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# D field info for plot
rmse_d = g4_df["RMSE_D_Original_values"]
station_name = g4_df["Code"]
# Figure
fig6, ax6 = plt.subplots()
ax6.scatter(station_name, rmse_d, marker = orig_symbol)
ax6.set_xlabel("Station name", fontsize=axis_label_fsize)
ax6.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax6.set_title(f"{component_d}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g4_fig_rmse_d, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# I field info for plot
rmse_i = g4_df["RMSE_I_Original_values"]
station_name = g4_df["Code"]
# Figure
fig7, ax7 = plt.subplots()
ax7.scatter(station_name, rmse_i, marker = orig_symbol)
ax7.set_xlabel("Station name", fontsize=axis_label_fsize)
ax7.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax7.set_title(f"{component_i}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g4_fig_rmse_i, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %% [markdown]
# ## Group 5

# %%
# F field info for plot
rmse_f = g5_df["RMSE_F_Original_values"]
station_name = g5_df["Code"]
# Figure
fig1, ax1 = plt.subplots()
ax1.scatter(station_name, rmse_f, marker = orig_symbol)
ax1.set_xlabel("Station name", fontsize=axis_label_fsize)
ax1.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax1.set_title(f"{component_f}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g5_fig_rmse_f, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# H field info for plot
rmse_h = g5_df["RMSE_H_Original_values"]
station_name = g5_df["Code"]
# Figure
fig2, ax2 = plt.subplots()
ax2.scatter(station_name, rmse_h, marker = orig_symbol)
ax2.set_xlabel("Station name", fontsize=axis_label_fsize)
ax2.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax2.set_title(f"{component_h}: Group with {n1} or {n2} more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g5_fig_rmse_h, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# X field info for plot
rmse_x_orig = g5_df["RMSE_X_Original_values"]
rmse_x_calc = g5_df["RMSE_X_Calculated_values"]
station_name = g5_df["Code"]
# Figure
fig3, ax3 = plt.subplots()
ax3.scatter(station_name, rmse_x_orig, marker = orig_symbol)
ax3.scatter(station_name, rmse_x_calc, marker = calc_symbol) 
ax3.set_xlabel("Station name", fontsize=axis_label_fsize)
ax3.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax3.set_title(f"{component_x}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g5_fig_rmse_x, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# Y field info for plot
rmse_y_orig = g5_df["RMSE_Y_Original_values"]
rmse_y_calc = g5_df["RMSE_Y_Calculated_values"]
station_name = g5_df["Code"]
# Figure
fig4, ax4 = plt.subplots()
ax4.scatter(station_name, rmse_y_orig, marker = orig_symbol)
ax4.scatter(station_name, rmse_y_calc, marker = "+")
ax4.set_xlabel("Station name", fontsize=axis_label_fsize)
ax4.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax4.set_title(f"{component_y}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g5_fig_rmse_y, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# Z field info for plot
rmse_z_orig = g5_df["RMSE_Z_Original_values"]
rmse_z_calc = g5_df["RMSE_Z_Calculated_values"]
station_name = g5_df["Code"]
# Figure
fig4, ax5 = plt.subplots()
ax5.scatter(station_name, rmse_z_orig, marker = orig_symbol)
ax5.scatter(station_name, rmse_z_calc, marker = "+")
ax5.set_xlabel("Station name", fontsize=axis_label_fsize)
ax5.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax5.set_title(f"{component_z}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g5_fig_rmse_z, dpi=dpi_quality, bbox_inches=value_bbox_inches)
#plt.close()
plt.show()

# %%
# D field info for plot
rmse_d = g5_df["RMSE_D_Original_values"]
station_name = g5_df["Code"]
# Figure
fig6, ax6 = plt.subplots()
ax6.scatter(station_name, rmse_d, marker = orig_symbol)
ax6.set_xlabel("Station name", fontsize=axis_label_fsize)
ax6.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax6.set_title(f"{component_d}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g5_fig_rmse_d, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()

# %%
# I field info for plot
rmse_i = g5_df["RMSE_I_Original_values"]
station_name = g5_df["Code"]
# Figure
fig7, ax7 = plt.subplots()
ax7.scatter(station_name, rmse_i, marker = orig_symbol)
ax7.set_xlabel("Station name", fontsize=axis_label_fsize)
ax7.set_ylabel("RMSE Value", fontsize=axis_label_fsize)
ax7.set_title(f"{component_i}: Group with {n1} or {n2} or more occupations", fontsize=title_fontsize)
plt.legend([orig_label, calc_label])
plt.xticks(rotation=90)
plt.savefig(output_folder / g5_fig_rmse_i, dpi=dpi_quality, bbox_inches=value_bbox_inches)
plt.show()
